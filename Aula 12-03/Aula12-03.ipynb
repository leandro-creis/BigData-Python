# %%
import pandas as pd
import numpy as np

XPTO = pd.read_excel('/content/drive/MyDrive/Uninove 1.2021/Python/DemoData.xlsx')
XPTO.head(10)
# Out:
#    Unnamed: 0  DT_ANALISE  ...  Atraso_Decay_180  QT_COPARTICIPACAO
# 0           0  2021-02-18  ...          0.021339                0.0
# 1           1  2021-02-18  ...          0.010645                1.0
# 2           2  2021-02-18  ...          0.017846                0.0
# 3           3  2021-02-18  ...          0.015317                0.0
# 4           4  2021-02-18  ...          0.000000                0.0
# 5           5  2021-02-18  ...          0.000000                0.0
# 6           6  2021-02-18  ...               NaN                NaN
# 7           7  2021-02-18  ...          0.003351                0.0
# 8           8  2021-02-18  ...          0.012066                0.0
# 9           9  2021-02-18  ...          0.020038                0.0
#
# [10 rows x 256 columns]

# %%
XPTO.ID_IDADE.tail(20)
# Out:
# 3980    37
# 3981    35
# 3982     7
# 3983    47
# 3984    53
# 3985    36
# 3986    52
# 3987    52
# 3988    30
# 3989    57
# 3990    26
# 3991    34
# 3992    93
# 3993    29
# 3994    56
# 3995    44
# 3996    17
# 3997    57
# 3998    40
# 3999    41
# Name: ID_IDADE, dtype: int64

# %%
XPTO.ID_IDADE.value_counts()
# Out:
# 39     120
# 38     113
# 35     112
# 28      98
# 32      97
#       ...
# 120      2
# 95       2
# 99       1
# 93       1
# 101      1
# Name: ID_IDADE, Length: 100, dtype: int64

# %%
XPTO.ID_IDADE.mean()
# Out:
# 38.142

# %%
XPTO.ID_IDADE.sum()/4000
# Out:
# 38.142

# %%
XPTO.ID_IDADE.median()
# Out:
# 37.0

# %%
XPTO.VR_PLANO
# Out:
# 0        698.1
# 1        203.5
# 2        968.7
# 3        786.6
# 4       1019.7
#          ...
# 3995    1077.7
# 3996     323.5
# 3997    1485.0
# 3998    1596.7
# 3999     759.2
# Name: VR_PLANO, Length: 4000, dtype: float64

# %%
XPTO.VR_PLANO.median()
# Out:
# 691.9

# %%
XPTO[XPTO['VR_PLANO']>691].VR_PLANO.mean()
# Out:
# 1668.597452547453
