# %%
import os
import pandas as pd
CURR_DIR = os.getcwd()
print(CURR_DIR)
df = pd.read_excel('/content/drive/MyDrive/Uninove 1.2021/Python/Aula 19 03/DemoData.xlsx')
df.head(10)
# Out:
# /content
#    Unnamed: 0  DT_ANALISE  ...  Atraso_Decay_180  QT_COPARTICIPACAO
# 0           0  2021-02-18  ...          0.021339                0.0
# 1           1  2021-02-18  ...          0.010645                1.0
# 2           2  2021-02-18  ...          0.017846                0.0
# 3           3  2021-02-18  ...          0.015317                0.0
# 4           4  2021-02-18  ...          0.000000                0.0
# 5           5  2021-02-18  ...          0.000000                0.0
# 6           6  2021-02-18  ...               NaN                NaN
# 7           7  2021-02-18  ...          0.003351                0.0
# 8           8  2021-02-18  ...          0.012066                0.0
# 9           9  2021-02-18  ...          0.020038                0.0
#
# [10 rows x 256 columns]

# %%
colunas = df.columns

# %%
colunas[0:10]
# Out:
# Index(['Unnamed: 0', 'DT_ANALISE', 'ID_SISTEMA_ORIGEM', 'ID_CONTRATO',
#        'ID_PESSOA', 'ID_OPERADORA', 'ID_ENTIDADE', 'ID_TIPO_PLANO_PRINCIPAL',
#        'ID_TIPO_CANCELAMENTO', 'ID_GEOGRAFIA'],
#       dtype='object')

# %%
for batata in colunas:
  print(batata)
# Out:
# Unnamed: 0
# DT_ANALISE
# ID_SISTEMA_ORIGEM
# ID_CONTRATO
# ID_PESSOA
# ID_OPERADORA
# ID_ENTIDADE
# ID_TIPO_PLANO_PRINCIPAL
# ID_TIPO_CANCELAMENTO
# ID_GEOGRAFIA
# ID_GEOGRAFIA_ENTIDADE
# ID_SITUACAO_CONTRATO
# ID_CLASS_CLIENTE
# ID_RISCO_CONTRATO
# ID_STATUS
# ID_GRAU_PARENTESCO
# ID_TEMPO_PERMANENCIA
# ID_JANELA_PAGTO
# ID_PRODUTO
# ID_SEGMENTACAO
# ID_FAIXA_ETARIA_ANS
# ID_IDADE
# ID_FAIXA_VALOR_CONTRATO
# ID_FAIXA_VALOR_VIDA
# FL_EXCLIENTE
# FL_RETORNADO_IMEDIATO
# FL_RETORNADO_POSTERIOR
# DT_INICIO
# DT_FIM
# QT_PLANO_ADICIONAL
# QT_COBRANCAS_AVENCER
# QT_COBRANCAS_VENCIDA
# QT_LIMINAR
# FL_UPGRADE_PLANO
# FL_DOWNGRADE_PLANO
# VR_PLANO
# VR_REPASSE
# DT_PROCESSAMENTO
# QT_MESES_PERMANENCIA
# QT_DIAS_PERMANENCIA
# ID_BENEFICIARIO
# ID_PRODUTOR
# ID_CANAL_VENDA
# CD_CONTRATO
# CD_PESSOA
# NU_MATRICULA
# CD_BENEFICIARIO
# CD_PRODUTOR
# FL_COPART
# CHURN
# PRÉ-CHURN
# CHURN_ATUAL
# PLANOS_P_PESSOA
# VR_PLANO_CLIENTE
# VR_REPASSE_CLIENTE
# VR_PLANO_CONTRATO
# VR_REPASSE_CONTRATO
# ...

# %%
df1 =  df[["ID_PRODUTO", "ID_IDADE", "VR_PLANO", "CHURN", "DS_SEXO", "SERASA", "TENURE", "IDHM 2010", "Atrasos_Ano"]]

# %%
df1
# Out:
#       ID_PRODUTO  ID_IDADE  VR_PLANO  ...  TENURE IDHM 2010  Atrasos_Ano
# 0         199464        40     698.1  ...  1205.0     0.799          7.0
# 1         230088        28     203.5  ...   701.0     0.810          4.0
# 2         199317        49     968.7  ...   871.0     0.739          7.0
# 3         199458        26     786.6  ...  1236.0     0.799          6.0
# 4           1311        36    1019.7  ...  4372.0     0.824          0.0
# ...          ...       ...       ...  ...     ...       ...          ...
# 3995      256888        44    1077.7  ...  1704.0     0.762          6.0
# 3996      177939        17     323.5  ...    91.0     0.805          NaN
# 3997      338878        57    1485.0  ...  2920.0     0.799          NaN
# 3998      337115        40    1596.7  ...   577.0     0.799          NaN
# 3999       20281        41     759.2  ...  4048.0       NaN          2.0
#
# [4000 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_PRODUTO   4000 non-null   int64
#  1   ID_IDADE     4000 non-null   int64
#  2   VR_PLANO     3991 non-null   float64
#  3   CHURN        4000 non-null   bool
#  4   DS_SEXO      4000 non-null   object
#  5   SERASA       4000 non-null   int64
#  6   TENURE       3982 non-null   float64
#  7   IDHM 2010    3725 non-null   float64
#  8   Atrasos_Ano  2853 non-null   float64
# dtypes: bool(1), float64(4), int64(3), object(1)
# memory usage: 254.0+ KB

# %%
df1.VR_PLANO.value_counts()
# Out:
# 262.8     52
# 150.5     37
# 190.5     29
# 139.4     25
# 249.6     25
#           ..
# 210.8      1
# 9378.0     1
# 500.5      1
# 345.5      1
# 987.1      1
# Name: VR_PLANO, Length: 2078, dtype: int64

# %%
df1.Atrasos_Ano.value_counts().sum()
# Out:
# 2853

# %%
df1.Atrasos_Ano.fillna(0,inplace= True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
df1.Atrasos_Ano.value_counts().sum()
# Out:
# 4000

# %%
df1.VR_PLANO.value_counts().sum()
# Out:
# 3991

# %%
df1 = df1[df1.VR_PLANO.notnull()]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_PRODUTO   4000 non-null   int64
#  1   ID_IDADE     4000 non-null   int64
#  2   VR_PLANO     3991 non-null   float64
#  3   CHURN        4000 non-null   bool
#  4   DS_SEXO      4000 non-null   object
#  5   SERASA       4000 non-null   int64
#  6   TENURE       3982 non-null   float64
#  7   IDHM 2010    3725 non-null   float64
#  8   Atrasos_Ano  4000 non-null   float64
# dtypes: bool(1), float64(4), int64(3), object(1)
# memory usage: 254.0+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3991 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_PRODUTO   3991 non-null   int64
#  1   ID_IDADE     3991 non-null   int64
#  2   VR_PLANO     3991 non-null   float64
#  3   CHURN        3991 non-null   bool
#  4   DS_SEXO      3991 non-null   object
#  5   SERASA       3991 non-null   int64
#  6   TENURE       3974 non-null   float64
#  7   IDHM 2010    3720 non-null   float64
#  8   Atrasos_Ano  3991 non-null   float64
# dtypes: bool(1), float64(4), int64(3), object(1)
# memory usage: 284.5+ KB

# %%
df1.CHURN.value_counts()
# Out:
# False    1999
# True     1992
# Name: CHURN, dtype: int64

# %%
df1.describe()
# Out:
#           ID_PRODUTO     ID_IDADE  ...    IDHM 2010  Atrasos_Ano
# count    3991.000000  3991.000000  ...  3720.000000  3991.000000
# mean   209953.774994    38.077675  ...     0.780216     2.612879
# std    120620.174397    18.660561  ...     0.036899     3.031452
# min        30.000000     1.000000  ...     0.627000     0.000000
# 25%    121439.000000    26.000000  ...     0.756000     0.000000
# 50%    227007.000000    37.000000  ...     0.799000     2.000000
# 75%    289048.500000    50.000000  ...     0.805000     5.000000
# max    610718.000000   120.000000  ...     0.862000    16.000000
#
# [8 rows x 7 columns]

# %%
df1.ID_IDADE.median()
# Out:
# 37.0
